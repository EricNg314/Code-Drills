# %%
# Import dependencies
    # You'll need Pandas

# %%
# Declare a variable called 'url' 
    # and set it to the following link 
    # 'https://en.wikipedia.org/wiki/List_of_2018_box_office_number-one_films_in_the_United_States'

# %%
# Declare a variable called 'tables' and use pandas to parse through the url to retrieve all table data within the url.
# Out:
# [     0                   1                                      2  \
#  0    #                Date                                   Film
#  1    1     January 7, 2018         Jumanji: Welcome to the Jungle
#  2    2    January 14, 2018         Jumanji: Welcome to the Jungle
#  3    3    January 21, 2018         Jumanji: Welcome to the Jungle
#  4    4    January 28, 2018            Maze Runner: The Death Cure
#  5    5    February 4, 2018         Jumanji: Welcome to the Jungle
#  6    6   February 11, 2018                     Fifty Shades Freed
#  7    7   February 18, 2018                          Black Panther
#  8    8   February 25, 2018                          Black Panther
#  9    9       March 4, 2018                          Black Panther
#  10  10      March 11, 2018                          Black Panther
#  11  11      March 18, 2018                          Black Panther
#  12  12      March 25, 2018                   Pacific Rim Uprising
# ...

# %%
# Check the type of data in tables, should be list.
# Out:
# list

# %%
# Set your new information in 'tables' to a dataframe.



# Give your dataframe new column names.


# Display the first 5 rows in the dataframe.
# Out:
#   Number              Date                            Film        Gross  \
# 0      #              Date                            Film        Gross
# 1      1   January 7, 2018  Jumanji: Welcome to the Jungle  $37,233,653
# 2      2  January 14, 2018  Jumanji: Welcome to the Jungle  $28,101,972
# 3      3  January 21, 2018  Jumanji: Welcome to the Jungle  $19,505,170
# 4      4  January 28, 2018     Maze Runner: The Death Cure  $24,167,011
#
#                                              Note(s)
# 0                                            Note(s)
# 1  Jumanji: Welcome to the Jungle reached #1 in i...
# 2                                                NaN
# 3  Jumanji: Welcome to the Jungle became the firs...
# 4                                                NaN

# %%
# Be sure to drop the first row, if they include the column names.


# Display the first 10 rows in the dataframe.
# Out:
#    Number               Date                            Film         Gross  \
# 1       1    January 7, 2018  Jumanji: Welcome to the Jungle   $37,233,653
# 2       2   January 14, 2018  Jumanji: Welcome to the Jungle   $28,101,972
# 3       3   January 21, 2018  Jumanji: Welcome to the Jungle   $19,505,170
# 4       4   January 28, 2018     Maze Runner: The Death Cure   $24,167,011
# 5       5   February 4, 2018  Jumanji: Welcome to the Jungle   $10,930,222
# 6       6  February 11, 2018              Fifty Shades Freed   $38,560,195
# 7       7  February 18, 2018                   Black Panther  $202,003,951
# 8       8  February 25, 2018                   Black Panther  $111,658,835
# 9       9      March 4, 2018                   Black Panther   $66,306,935
# 10     10     March 11, 2018                   Black Panther   $40,817,579
#
#                                               Note(s)
# 1   Jumanji: Welcome to the Jungle reached #1 in i...
# ...

# %%
# Save the data as an html.
